# %%
# %matplotlib inline
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Exploratory Data Analysis

# %%
pd.set_option("display.max_rows", None, "display.max_columns", None)

# %%
# Reading the data
df = pd.read_csv("../Data/bestsellers with categories.csv")
# Getting the top five rows of the data
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
# Checking the data types of each features
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
# Checking if there is NaN Values
df.isna().sum()
# Out:
# Name           0
# Author         0
# User Rating    0
# Reviews        0
# Price          0
# Year           0
# Genre          0
# dtype: int64

# %%
# Summary Statistics of the data
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %% [markdown]
# ## Q1: What books have the highest consistent rating?

# %%
df[df["User Rating"] == df["User Rating"].max()]
# Out:
#                                                   Name                 Author  \
# 40            Brown Bear, Brown Bear, What Do You See?        Bill Martin Jr.
# 41            Brown Bear, Brown Bear, What Do You See?        Bill Martin Jr.
# 81   Dog Man and Cat Kid: From the Creator of Capta...             Dav Pilkey
# 82   Dog Man: A Tale of Two Kitties: From the Creat...             Dav Pilkey
# 83   Dog Man: Brawl of the Wild: From the Creator o...             Dav Pilkey
# 84   Dog Man: Brawl of the Wild: From the Creator o...             Dav Pilkey
# 85   Dog Man: Fetch-22: From the Creator of Captain...             Dav Pilkey
# 86   Dog Man: For Whom the Ball Rolls: From the Cre...             Dav Pilkey
# 87   Dog Man: Lord of the Fleas: From the Creator o...             Dav Pilkey
# 146  Goodnight, Goodnight Construction Site (Hardco...   Sherri Duskey Rinker
# 147  Goodnight, Goodnight Construction Site (Hardco...   Sherri Duskey Rinker
# ...

# %% [markdown]
# ## Q2: What book/s have the lowest rating?

# %%
df[df["User Rating"] < 4]
# Out:
#                                                   Name         Author  \
# 22                                           Allegiant  Veronica Roth
# 106  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 107  Fifty Shades of Grey: Book One of the Fifty Sh...      E L James
# 132                         Go Set a Watchman: A Novel     Harper Lee
# 353                                 The Casual Vacancy   J.K. Rowling
# 392  The Goldfinch: A Novel (Pulitzer Prize for Fic...    Donna Tartt
# 393  The Goldfinch: A Novel (Pulitzer Prize for Fic...    Donna Tartt
#
#      User Rating  Reviews  Price  Year    Genre
# 22           3.9     6310     13  2013  Fiction
# 106          3.8    47265     14  2012  Fiction
# 107          3.8    47265     14  2013  Fiction
# 132          3.6    14982     19  2015  Fiction
# 353          3.3     9372     12  2012  Fiction
# 392          3.9    33844     20  2013  Fiction
# 393          3.9    33844     20  2014  Fiction

# %% [markdown]
# ## Q3: Common Authors

# %%
common_authors = df.groupby("Author").count().reset_index().sort_values("Name", ascending=False).head(28)
common_authors
# Out:
#                                  Author  Name  User Rating  Reviews  Price  \
# 120                         Jeff Kinney    12           12       12     12
# 92                         Gary Chapman    11           11       11     11
# 226                     Suzanne Collins    11           11       11     11
# 197                        Rick Riordan    11           11       11     11
# 11   American Psychological Association    10           10       10     10
# 90                               Gallup     9            9        9      9
# 73                            Dr. Seuss     9            9        9      9
# 199                         Rob Elliott     8            8        8      8
# 83                           Eric Carle     7            7        7      7
# 27                        Bill O'Reilly     7            7        7      7
# 58                           Dav Pilkey     7            7        7      7
# ...

# %% [markdown]
# ## Most Reviewed Book/s

# %%
df[df["Reviews"] == df["Reviews"].max()]
# Out:
#                         Name       Author  User Rating  Reviews  Price  Year  \
# 534  Where the Crawdads Sing  Delia Owens          4.8    87841     15  2019
#
#        Genre
# 534  Fiction

# %% [markdown]
# ## What books have the lowest reviews

# %%
df[df["Reviews"] == df["Reviews"].min()]
# Out:
#                                                  Name        Author  \
# 78  Divine Soul Mind Body Healing and Transmission...  Zhi Gang Sha
#
#     User Rating  Reviews  Price  Year        Genre
# 78          4.6       37      6  2009  Non Fiction

# %% [markdown]
# ## Number of Fiction and Non-Fiction Books

# %%
df["Genre"].value_counts()
# Out:
# Non Fiction    310
# Fiction        240
# Name: Genre, dtype: int64

# %% [markdown]
# ## Is User rating correlates to reviews

# %%
user_rating = df["User Rating"]
reviews = df["Reviews"]
user_rating.corr(reviews)
# Out:
# -0.0017290142555499656

# %% [markdown]
# ## Most expensive Books

# %%
df[df["Price"] == df["Price"].max()]
# Out:
#                                                  Name  \
# 69  Diagnostic and Statistical Manual of Mental Di...
# 70  Diagnostic and Statistical Manual of Mental Di...
#
#                               Author  User Rating  Reviews  Price  Year  \
# 69  American Psychiatric Association          4.5     6679    105  2013
# 70  American Psychiatric Association          4.5     6679    105  2014
#
#           Genre
# 69  Non Fiction
# 70  Non Fiction

# %% [markdown]
# ## User rating based on genre

# %%
pd.crosstab(df.Genre, df["User Rating"])
# Out:
# User Rating  3.3  3.6  3.8  3.9  4.0  4.1  4.2  4.3  4.4  4.5  4.6  4.7  4.8  \
# Genre
# Fiction        1    1    2    3    5    4    3   11   10   18   31   34   76
# Non Fiction    0    0    0    0    9    2    5   14   28   42   74   74   51
#
# User Rating  4.9
# Genre
# Fiction       41
# Non Fiction   11

# %% [markdown]
# ## Duplicated Samples

# %%
df_duplicated = df[df.duplicated(["Name"])]
df_duplicated
# Out:
#                                                   Name  \
# 10                           A Man Called Ove: A Novel
# 21                         All the Light We Cannot See
# 33                                            Becoming
# 36                            Between the World and Me
# 41            Brown Bear, Brown Bear, What Do You See?
# 47                    Catching Fire (The Hunger Games)
# 48                    Catching Fire (The Hunger Games)
# 51         Crazy Love: Overwhelmed by a Relentless God
# 52         Crazy Love: Overwhelmed by a Relentless God
# 57                                   Cutting for Stone
# 64                      Dear Zoo: A Lift-the-Flap Book
# 65                      Dear Zoo: A Lift-the-Flap Book
# 66                      Dear Zoo: A Lift-the-Flap Book
# 70   Diagnostic and Statistical Manual of Mental Di...
# 76                                           Divergent
# 84   Dog Man: Brawl of the Wild: From the Creator o...
# ...

# %% [markdown]
# ## Some Visualization

# %%
df["User Rating"].hist();

# %%
df["Reviews"].hist();

# %%
sns.boxplot(x="Genre", y=df["User Rating"], data=df);

# %%
plt.scatter(x=df["User Rating"], y=df["Reviews"], c="salmon");

# %%
df.head()
# Out:
#                                                 Name  \
# 0                      10-Day Green Smoothie Cleanse
# 1                                  11/22/63: A Novel
# 2            12 Rules for Life: An Antidote to Chaos
# 3                             1984 (Signet Classics)
# 4  5,000 Awesome Facts (About Everything!) (Natio...
#
#                      Author  User Rating  Reviews  Price  Year        Genre
# 0                  JJ Smith          4.7    17350      8  2016  Non Fiction
# 1              Stephen King          4.6     2052     22  2011      Fiction
# 2        Jordan B. Peterson          4.7    18979     15  2018  Non Fiction
# 3             George Orwell          4.7    21424      6  2017      Fiction
# 4  National Geographic Kids          4.8     7665     12  2019  Non Fiction

# %%
fig = plt.figure(figsize=(15, 10), dpi = 75)
plt.bar(common_authors["Author"], common_authors["Name"], color=["salmon"])
plt.title("Common Authors")
plt.ylabel("Count")
plt.xlabel("Authors")
plt.xticks(rotation=50);
plt.yticks(rotation=90);
